# %%
import pandas as pd
import numpy as np

PATH="~/tensorflow_projekte/titanic/"

train_data=pd.read_csv(PATH + "data/train.csv", index_col=0)

# %%
"""Variable	Definition	Key
survival 	Survival 	0 = No, 1 = Yes
pclass 	Ticket class 	1 = 1st, 2 = 2nd, 3 = 3rd
sex 	Sex 	
Age 	Age in years 	
sibsp 	# of siblings / spouses aboard the Titanic 	
parch 	# of parents / children aboard the Titanic 	
ticket 	Ticket number 	
fare 	Passenger fare 	
cabin 	Cabin number 	
embarked 	Port of Embarkation 	C = Cherbourg, Q = Queenstown, S = Southampton
"""
train_data
# Out:
#              Survived  Pclass  Sex_r        Age  SibSp  Parch      Fare  \
# PassengerId
# 1                   0       3      1  22.000000      1      0    7.2500
# 2                   1       1      0  38.000000      1      0   71.2833
# 3                   1       3      0  26.000000      0      0    7.9250
# 4                   1       1      0  35.000000      1      0   53.1000
# 5                   0       3      1  35.000000      0      0    8.0500
# 6                   0       3      1  29.699118      0      0    8.4583
# 7                   0       1      1  54.000000      0      0   51.8625
# 8                   0       3      1   2.000000      3      1   21.0750
# 9                   1       3      0  27.000000      0      2   11.1333
# 10                  1       2      0  14.000000      1      0   30.0708
# 11                  1       3      0   4.000000      1      1   16.7000
# 12                  1       1      0  58.000000      0      0   26.5500
# ...

# %%
train_data["Cabin_Code"]=train_data["Cabin"].str[0]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
train_data["Sex_r"]=le.fit_transform(train_data["Sex"])
train_data["Embarked_r"]=le.fit_transform(train_data["Embarked"].astype(str))
train_data["Cabin_Code_r"]=le.fit_transform(train_data["Cabin_Code"].astype(str))

# %%
for x in ["Pclass","Sex_r","Age","SibSp","Parch","Fare"]:
    train_data[x].fillna(train_data[x].mean(), inplace=True)

# %%
train_data=train_data[["Survived","Pclass","Sex_r","Age","SibSp","Parch","Fare", "Embarked_r","Cabin_Code_r"]].copy(deep=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_data.iloc[:,1:], train_data.iloc[:,0], test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

clf = RandomForestClassifier(max_depth=20, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print(clf.feature_importances_)
# Out:
# [0.09467561 0.22113379 0.23710215 0.04422136 0.03726611 0.23104573
#  0.03732857 0.09722669]

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      0.83      0.81       175
#           1       0.73      0.68      0.70       120
#
# avg / total       0.76      0.77      0.76       295

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV

param_grid = [
  {'max_depth':[10,15,20,25,30], 'n_estimators':[10,50,80,100,200]}
 ]

grid_search = GridSearchCV(clf, param_grid=param_grid)

grid_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b75b86ed253b> in <module>()
#      10 grid_search.fit(X_train, y_train)
#      11
# ---> 12 report(grid_search.cv_results_)
#
# NameError: name 'report' is not defined

# %%
print(grid_search.best_params_ )
# Out:
# {'max_depth': 10, 'n_estimators': 200}

# %%
clf = RandomForestClassifier(max_depth=10, n_estimators=200, random_state=0)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.87      0.84       175
#           1       0.79      0.70      0.74       120
#
# avg / total       0.80      0.80      0.80       295
